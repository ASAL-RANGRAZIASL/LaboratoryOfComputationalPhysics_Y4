# %% [markdown]
# # Pandas
#
# The `numpy` module is excellent for numerical computations, but to handle missing data or arrays with mixed types takes more work. The `pandas` module is currently the most widely used tool for data manipulation, providing high-performance, easy-to-use data structures and advanced data analysis tools.
#
# In particular `pandas` features:
#
# * A fast and efficient "DataFrame" object for data manipulation with integrated indexing;
# * Tools for reading and writing data between in-memory data structures and different formats (CSV, Excel, SQL, HDF5);
# * Intelligent data alignment and integrated handling of missing data;
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
# * Aggregating or transforming data with a powerful "group-by" engine;
# * High performance merging and joining of data sets;
# * Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
# * Time series-functionalities;
# * Highly optimized for performance, with critical code paths written in Cython or C.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
#
# Series are completely equivalent to 1D array but with axis labels and the possibility to store heterogeneous elements. Of paramount importance are the time-series, used to define time evolutions of a phenomenon.

# %%
from string import ascii_lowercase as letters

# Creating a series, accessing indexes, values and values by their index 
xs = pd.Series(np.arange(10)*0.5, index=tuple(letters[:10]))
print ("xs:", xs,'\n')
print ("xs indexes:",xs.index,'\n')
# Values of the Series are actually a numpy array
print ("xs values:", xs.values, type(xs.values),'\n')
print (xs['f'], xs.f, xs.h, '\n') #each indexes(such f) can work as method
print (xs[['d', 'f', 'h']], '\n')
print (type(xs[['d', 'f', 'h']]), '\n')
# Out:
# xs: a    0.0
# b    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# g    3.0
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# xs indexes: Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
#
# xs values: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5] <class 'numpy.ndarray'>
#
# 2.5 2.5 3.5
#
# d    1.5
# f    2.5
# h    3.5
# dtype: float64
#
# <class 'pandas.core.series.Series'>

# %%
# Extracting elements and operations: same as numpy array
print (xs[:3],'\n')
print (xs[7:], '\n')
print (xs[::3], '\n')# begining:end:step
print (xs[xs>3], '\n')
print (np.exp(xs), '\n')# you can put it ib function(apply to every element of sereis)
print (np.mean(xs), np.std(xs), '\n')
# Out:
# a    0.0
# b    0.5
# c    1.0
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a    0.0
# d    1.5
# g    3.0
# j    4.5
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a     1.000000
# b     1.648721
# c     2.718282
# d     4.481689
# e     7.389056
# f    12.182494
# g    20.085537
# h    33.115452
# i    54.598150
# j    90.017131
# dtype: float64
#
# 2.25 1.4361406616345072

# %%
# Series can be created from python dictionary too.
# Not that the elements can be whatever!
d = {'b' : 1, 'a' : 'cat', 'c' : [2,3]}#standard dictionary
pd.Series(d)
# Out:
# b         1
# a       cat
# c    [2, 3]
# dtype: object

# %% [markdown]
# A key difference between Series and ndarray is that operations between Series automatically align the data based on label. Thus, you can write computations without considering whether the Series involved have the same labels.

# %%
s = pd.Series(np.random.randn(5), index=tuple(letters[:5]))
print(s)
s = s[1:] + s[:-1]
print(s)
# Out:
# a    0.428964
# b   -0.762473
# c    0.778337
# d    1.543934
# e   -0.487191
# dtype: float64
# a         NaN
# b   -1.524945
# c    1.556675
# d    3.087868
# e         NaN
# dtype: float64

# %% [markdown]
# ### Time series
#
# Time series are very often used to profile the behaviour of a quantity as a function of time. Pandas has a special index for that, `DatetimeIndex`, that can be created e.g. with the function `pd.data_range()`

# %%
# to define a date, the datetime module is very useful
import datetime as dt
date = dt.date.today()
print(date)

date = dt.datetime(2021,11,22,12,45,10,15) #year,month,day,hour,min,secon,...
print (date)

# otherwise, several notations are interpreted too
date = 'Nov 22 2021'
# or alternatively
date = '22/11/2021 12:45:00'
print (date)

days = pd.date_range(date, periods=7, freq='D') #d means day
print (days)

seconds = pd.date_range(date, periods=3600, freq='s')
print (seconds)
# Out:
# 2021-11-22
# 2021-11-22 12:45:10.000015
# 22/11/2021 12:45:00
# DatetimeIndex(['2021-11-22 12:45:00', '2021-11-23 12:45:00',
#                '2021-11-24 12:45:00', '2021-11-25 12:45:00',
#                '2021-11-26 12:45:00', '2021-11-27 12:45:00',
#                '2021-11-28 12:45:00'],
#               dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2021-11-22 12:45:00', '2021-11-22 12:45:01',
#                '2021-11-22 12:45:02', '2021-11-22 12:45:03',
#                '2021-11-22 12:45:04', '2021-11-22 12:45:05',
#                '2021-11-22 12:45:06', '2021-11-22 12:45:07',
#                '2021-11-22 12:45:08', '2021-11-22 12:45:09',
#                ...
#                '2021-11-22 13:44:50', '2021-11-22 13:44:51',
#                '2021-11-22 13:44:52', '2021-11-22 13:44:53',
#                '2021-11-22 13:44:54', '2021-11-22 13:44:55',
#                '2021-11-22 13:44:56', '2021-11-22 13:44:57',
#                '2021-11-22 13:44:58', '2021-11-22 13:44:59'],
# ...

# %% [markdown]
# To learn more about the frequency strings, please see this [link](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)
#
#
# Timestamped data is the most basic type of time series data that associates values with points in time. For pandas objects it means using the points in time.
#
# functions like `pd.to_datetime` can be used, for instance, when reading information as string from a dataset.
#
# Timestamp is the pandas equivalent of python’s Datetime and is interchangeable with it in most cases.

# %%
tstamp = pd.Timestamp(dt.datetime(2020, 11, 9))

# internally it counts the nanoseconds from January 1st 19
#tstamp = pd.Timestamp(dt.datetime(1970, 1, 1, 0, 0, 0, 1))
print(tstamp.value)

# when creating a timestamp the format can be explicitly passed
ts = pd.to_datetime('2010/11/12', format='%Y/%m/%d')
print (type(ts))
print (ts.value)
ts = pd.to_datetime('12-11-2010 00:00', format='%d-%m-%Y %H:%M')
print (ts)
print (ts.value)
# Out:
# 1604880000000000000
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 1289520000000000000
# 2010-11-12 00:00:00
# 1289520000000000000

# %% [markdown]
# A standard series can be created and (range of) elements can be used as indexes

# %%
tseries = pd.Series(np.random.normal(10, 1, len(days)), index=days)
# Extracting elements
print (tseries[0:4], '\n')
print (tseries['2021-11-22':'2021-11-25'], '\n') # Note - includes end time
# Out:
# 2021-11-22 12:45:00    10.801125
# 2021-11-23 12:45:00    11.110975
# 2021-11-24 12:45:00    10.157190
# 2021-11-25 12:45:00     9.550526
# Freq: D, dtype: float64
#
# 2021-11-22 12:45:00    10.801125
# 2021-11-23 12:45:00    11.110975
# 2021-11-24 12:45:00    10.157190
# 2021-11-25 12:45:00     9.550526
# Freq: D, dtype: float64

# %% [markdown]
# `pd.to_datetime` can also be used to create a `DatetimeIndex`:

# %%
pd.to_datetime([1, 2, 3, 4], unit='D', origin=pd.Timestamp('1980-02-03'))
# Out:
# DatetimeIndex(['1980-02-04', '1980-02-05', '1980-02-06', '1980-02-07'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## DataFrame
#
# A pandas DataFrame is like a simple tabular spreadsheet. For future reference (or for people already familiar with R), a pandas DataFrame is very similar to the R DataFrame.
#
# Each column in a DataFrame is a Series object.
#
# The element can be whatever, missing data are dealt with too (as NaN)

# %% [markdown]
# ### DataFrame creation
#
# A DataFrame can be created implicitly, with, e.g., a DatatimeIndex object as index:

# %%
entries=10
dates=pd.date_range('11/22/2021 12:45:00',freq='h', periods=entries)
df = pd.DataFrame(np.random.randn(entries,4), index=dates, columns=['A','B','C','D'])#we are going to have 4 value for each a,b,c,d
df
# Out:
#                             A         B         C         D
# 2021-11-22 12:45:00 -0.323254  0.979761  0.154588  0.101886
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  1.202681
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  0.417589
# 2021-11-22 15:45:00 -0.370052 -0.143113 -0.252981 -0.947085
# 2021-11-22 16:45:00 -1.805293 -0.919093 -0.794770  0.146903
# 2021-11-22 17:45:00  0.364801  0.371707 -1.171848 -0.011637
# 2021-11-22 18:45:00  2.010939  0.925543 -2.027292 -0.564135
# 2021-11-22 19:45:00 -0.071329  0.038003  0.580118  0.145507
# 2021-11-22 20:45:00  1.445956 -1.040189  0.228217 -0.787491
# 2021-11-22 21:45:00  0.182061 -0.288185 -0.268817  0.102908

# %% [markdown]
# or by means of a dictionary:

# %%
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=range(4),dtype='float32'),
      'D' : np.arange(7,11),# if you put 12 , it recieve error because you have 4 elements
      'E' : pd.Categorical(["test","train","test","train"]),
    }
    )
df2

# check what happens if D and E had different lenghts
# Out:
#      A          B    C   D      E
# 0  1.0 2013-01-02  1.0   7   test
# 1  1.0 2013-01-02  1.0   8  train
# 2  1.0 2013-01-02  1.0   9   test
# 3  1.0 2013-01-02  1.0  10  train

# %% [markdown]
# ### Viewing Data

# %%
df.head(2)
# Out:
#                             A         B         C         D
# 2021-11-22 12:45:00 -0.323254  0.979761  0.154588  0.101886
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  1.202681

# %%
df.tail(4)
# Out:
#                             A         B         C         D
# 2021-11-22 18:45:00  2.010939  0.925543 -2.027292 -0.564135
# 2021-11-22 19:45:00 -0.071329  0.038003  0.580118  0.145507
# 2021-11-22 20:45:00  1.445956 -1.040189  0.228217 -0.787491
# 2021-11-22 21:45:00  0.182061 -0.288185 -0.268817  0.102908

# %%
df.index
# Out:
# DatetimeIndex(['2021-11-22 12:45:00', '2021-11-22 13:45:00',
#                '2021-11-22 14:45:00', '2021-11-22 15:45:00',
#                '2021-11-22 16:45:00', '2021-11-22 17:45:00',
#                '2021-11-22 18:45:00', '2021-11-22 19:45:00',
#                '2021-11-22 20:45:00', '2021-11-22 21:45:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.32325422,  0.97976105,  0.15458787,  0.10188612],
#        [ 0.98364553, -0.02124176,  0.0580031 ,  1.20268132],
#        [ 0.23145755,  0.68386776,  0.84300715,  0.41758878],
#        [-0.37005196, -0.14311334, -0.25298092, -0.9470854 ],
#        [-1.80529286, -0.91909259, -0.79476978,  0.14690283],
#        [ 0.36480087,  0.37170661, -1.17184782, -0.01163706],
#        [ 2.01093881,  0.92554292, -2.02729193, -0.56413519],
#        [-0.07132941,  0.03800279,  0.5801181 ,  0.14550736],
#        [ 1.44595574, -1.0401889 ,  0.2282168 , -0.78749133],
#        [ 0.18206121, -0.28818469, -0.26881684,  0.10290803]])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.264893   0.058706  -0.265177  -0.019287
# std     1.060709   0.700800   0.861163   0.625062
# min    -1.805293  -1.040189  -2.027292  -0.947085
# 25%    -0.260273  -0.251917  -0.663282  -0.426011
# 50%     0.206759   0.008381  -0.097489   0.102397
# 75%     0.828934   0.605827   0.209810   0.146554
# max     2.010939   0.979761   0.843007   1.202681

# %%
df.T #see indexes and columns
# Out:
#    2021-11-22 12:45:00  2021-11-22 13:45:00  2021-11-22 14:45:00  \
# A            -0.323254             0.983646             0.231458
# B             0.979761            -0.021242             0.683868
# C             0.154588             0.058003             0.843007
# D             0.101886             1.202681             0.417589
#
#    2021-11-22 15:45:00  2021-11-22 16:45:00  2021-11-22 17:45:00  \
# A            -0.370052            -1.805293             0.364801
# B            -0.143113            -0.919093             0.371707
# C            -0.252981            -0.794770            -1.171848
# D            -0.947085             0.146903            -0.011637
#
#    2021-11-22 18:45:00  2021-11-22 19:45:00  2021-11-22 20:45:00  \
# A             2.010939            -0.071329             1.445956
# B             0.925543             0.038003            -1.040189
# C            -2.027292             0.580118             0.228217
# ...

# %%
df.sort_index(axis=0,ascending=True)
# Out:
#                             A         B         C         D
# 2021-11-22 12:45:00 -0.323254  0.979761  0.154588  0.101886
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  1.202681
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  0.417589
# 2021-11-22 15:45:00 -0.370052 -0.143113 -0.252981 -0.947085
# 2021-11-22 16:45:00 -1.805293 -0.919093 -0.794770  0.146903
# 2021-11-22 17:45:00  0.364801  0.371707 -1.171848 -0.011637
# 2021-11-22 18:45:00  2.010939  0.925543 -2.027292 -0.564135
# 2021-11-22 19:45:00 -0.071329  0.038003  0.580118  0.145507
# 2021-11-22 20:45:00  1.445956 -1.040189  0.228217 -0.787491
# 2021-11-22 21:45:00  0.182061 -0.288185 -0.268817  0.102908

# %%
df.sort_values(by="C")#min value of the c and grows
# Out:
#                             A         B         C         D
# 2021-11-22 18:45:00  2.010939  0.925543 -2.027292 -0.564135
# 2021-11-22 17:45:00  0.364801  0.371707 -1.171848 -0.011637
# 2021-11-22 16:45:00 -1.805293 -0.919093 -0.794770  0.146903
# 2021-11-22 21:45:00  0.182061 -0.288185 -0.268817  0.102908
# 2021-11-22 15:45:00 -0.370052 -0.143113 -0.252981 -0.947085
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  1.202681
# 2021-11-22 12:45:00 -0.323254  0.979761  0.154588  0.101886
# 2021-11-22 20:45:00  1.445956 -1.040189  0.228217 -0.787491
# 2021-11-22 19:45:00 -0.071329  0.038003  0.580118  0.145507
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  0.417589

# %% [markdown]
# ## Selection
#
# ### Getting slices
#
# The following show how to get part of the DataFrame (i.e. not just the elements)

# %%
## standard and safe
print (df['A'],'\n')

## equivalent but dangerous (imagine blank spaces in the name of the column..)
print (df.A) #the label become method! it works just when the name is good one not always!
# Out:
# 2021-11-22 12:45:00   -0.323254
# 2021-11-22 13:45:00    0.983646
# 2021-11-22 14:45:00    0.231458
# 2021-11-22 15:45:00   -0.370052
# 2021-11-22 16:45:00   -1.805293
# 2021-11-22 17:45:00    0.364801
# 2021-11-22 18:45:00    2.010939
# 2021-11-22 19:45:00   -0.071329
# 2021-11-22 20:45:00    1.445956
# 2021-11-22 21:45:00    0.182061
# Freq: H, Name: A, dtype: float64
#
# 2021-11-22 12:45:00   -0.323254
# 2021-11-22 13:45:00    0.983646
# 2021-11-22 14:45:00    0.231458
# 2021-11-22 15:45:00   -0.370052
# 2021-11-22 16:45:00   -1.805293
# 2021-11-22 17:45:00    0.364801
# 2021-11-22 18:45:00    2.010939
# 2021-11-22 19:45:00   -0.071329
# 2021-11-22 20:45:00    1.445956
# 2021-11-22 21:45:00    0.182061
# Freq: H, Name: A, dtype: float64

# %%
# selecting rows by counting
print (df[0:3])#give me the firts three rows,just counting rows

# or by index
print (df["2021-11-22 12:45:00":"2021-11-22 14:45:00"])#start and end point
# Out:
#                             A         B         C         D
# 2021-11-22 12:45:00 -0.323254  0.979761  0.154588  0.101886
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  1.202681
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  0.417589
#                             A         B         C         D
# 2021-11-22 12:45:00 -0.323254  0.979761  0.154588  0.101886
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  1.202681
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  0.417589

# %% [markdown]
# ### Selection by label

# %%
# getting a cross section (part of the DataFrame) using a label
df.loc[dates[0]] #you are going to have series
# Out:
# A   -0.323254
# B    0.979761
# C    0.154588
# D    0.101886
# Name: 2021-11-22 12:45:00, dtype: float64

# %%
# selecting on a multi-axis by label:
df.loc[:,['A','B']]
#a=df.loc[:,['A','B']]
# Out:
#                             A         B
# 2021-11-22 12:45:00 -0.323254  0.979761
# 2021-11-22 13:45:00  0.983646 -0.021242
# 2021-11-22 14:45:00  0.231458  0.683868
# 2021-11-22 15:45:00 -0.370052 -0.143113
# 2021-11-22 16:45:00 -1.805293 -0.919093
# 2021-11-22 17:45:00  0.364801  0.371707
# 2021-11-22 18:45:00  2.010939  0.925543
# 2021-11-22 19:45:00 -0.071329  0.038003
# 2021-11-22 20:45:00  1.445956 -1.040189
# 2021-11-22 21:45:00  0.182061 -0.288185

# %%
# showing label slicing, both endpoints are included:
df.loc['2021-11-22 16:45:00':'2021-11-22 18:45:00',['A','B']]
# Out:
#                             A         B
# 2021-11-22 16:45:00 -1.805293 -0.919093
# 2021-11-22 17:45:00  0.364801  0.371707
# 2021-11-22 18:45:00  2.010939  0.925543

# %%
# getting an individual element
print (df.loc[dates[1],'A'])

# equivalently
print (df.at[dates[1],'A'])
# Out:
# 0.9836455297775801
# 0.9836455297775801

# %% [markdown]
# ### Selecting by position

# %%
# select via the position of the passed integers:
print (df.iloc[3],'\n')

# notation similar to numpy/python
print (df.iloc[3:5,0:2])#first dimention & second dimention

# %%
# selecting raws 1,2 and 4 for columns 0 and 2
df.iloc[[1,2,4],[0,2]]

# %%
# slicing rows explicitly
print (df.iloc[1:3,:],'\n')

# slicing columns explicitly
print (df.iloc[:,1:3])

# %%
# selecting an individual element by position
df.iloc[1,1]
df.iat[1,1]

# %% [markdown]
# ### Boolean index
#
# Very powerful way of filtering out data with certain features. Notation is very similar to numpy arrays.

# %%
# Filter by a boolean condition on the values of a single column
df[df['B'] > 0]#have several enteries and want repeat it for each entery
#df>0
# df['B'] > 0
# Out:
#                          A      B      C      D
# 2021-11-22 12:45:00  False   True   True   True
# 2021-11-22 13:45:00   True  False   True   True
# 2021-11-22 14:45:00   True   True   True   True
# 2021-11-22 15:45:00  False  False  False  False
# 2021-11-22 16:45:00  False  False  False   True
# 2021-11-22 17:45:00   True   True  False  False
# 2021-11-22 18:45:00   True   True  False  False
# 2021-11-22 19:45:00  False   True   True   True
# 2021-11-22 20:45:00   True  False   True  False
# 2021-11-22 21:45:00   True  False  False   True

# %%
# Selecting on the basis of boolean conditions applied to the whole DataFrame
df[df>0]

# a DataFrame with the same shape is returned, with NaN's where condition is not met
# Out:
#                             A         B         C         D
# 2021-11-22 12:45:00       NaN  0.979761  0.154588  0.101886
# 2021-11-22 13:45:00  0.983646       NaN  0.058003  1.202681
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  0.417589
# 2021-11-22 15:45:00       NaN       NaN       NaN       NaN
# 2021-11-22 16:45:00       NaN       NaN       NaN  0.146903
# 2021-11-22 17:45:00  0.364801  0.371707       NaN       NaN
# 2021-11-22 18:45:00  2.010939  0.925543       NaN       NaN
# 2021-11-22 19:45:00       NaN  0.038003  0.580118  0.145507
# 2021-11-22 20:45:00  1.445956       NaN  0.228217       NaN
# 2021-11-22 21:45:00  0.182061       NaN       NaN  0.102908

# %% [markdown]
# ### Setting
#
# Combination of selection and setting of values

# %%
# setting values by label (same as by position)
df.at[dates[0],'A'] = 0

# setting and assigning a numpy array
df.loc[:,'D'] = np.array([5] * len(df))

# defining a brend new column
df['E'] = np.arange(len(df))*0.5

# defining a brend new column by means of a pd.Series: indexes must be the same!
df['E prime'] = pd.Series(np.arange(len(df))*2, index=df.index)

# %%
def dcos(theta):
    theta = theta*(np.pi/180)
    return np.cos(theta)
 
df['cosine'] = pd.Series(df["E"].apply(dcos), index=df.index)
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2021-11-22 12:45:00  0.000000  0.979761  0.154588  5  0.0        0  1.000000
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  5  0.5        2  0.999962
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  5  1.0        4  0.999848
# 2021-11-22 15:45:00 -0.370052 -0.143113 -0.252981  5  1.5        6  0.999657
# 2021-11-22 16:45:00 -1.805293 -0.919093 -0.794770  5  2.0        8  0.999391
# 2021-11-22 17:45:00  0.364801  0.371707 -1.171848  5  2.5       10  0.999048
# 2021-11-22 18:45:00  2.010939  0.925543 -2.027292  5  3.0       12  0.998630
# 2021-11-22 19:45:00 -0.071329  0.038003  0.580118  5  3.5       14  0.998135
# 2021-11-22 20:45:00  1.445956 -1.040189  0.228217  5  4.0       16  0.997564
# 2021-11-22 21:45:00  0.182061 -0.288185 -0.268817  5  4.5       18  0.996917

# %%
# another example of global setting
df2=df.copy()

df2[df2>0] = -df2
df2
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2021-11-22 12:45:00  0.000000 -0.979761 -0.154588 -5  0.0        0 -1.000000
# 2021-11-22 13:45:00 -0.983646 -0.021242 -0.058003 -5 -0.5       -2 -0.999962
# 2021-11-22 14:45:00 -0.231458 -0.683868 -0.843007 -5 -1.0       -4 -0.999848
# 2021-11-22 15:45:00 -0.370052 -0.143113 -0.252981 -5 -1.5       -6 -0.999657
# 2021-11-22 16:45:00 -1.805293 -0.919093 -0.794770 -5 -2.0       -8 -0.999391
# 2021-11-22 17:45:00 -0.364801 -0.371707 -1.171848 -5 -2.5      -10 -0.999048
# 2021-11-22 18:45:00 -2.010939 -0.925543 -2.027292 -5 -3.0      -12 -0.998630
# 2021-11-22 19:45:00 -0.071329 -0.038003 -0.580118 -5 -3.5      -14 -0.998135
# 2021-11-22 20:45:00 -1.445956 -1.040189 -0.228217 -5 -4.0      -16 -0.997564
# 2021-11-22 21:45:00 -0.182061 -0.288185 -0.268817 -5 -4.5      -18 -0.996917

# %%
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2021-11-22 12:45:00  0.000000  0.979761  0.154588  5  0.0        0  1.000000
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  5  0.5        2  0.999962
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  5  1.0        4  0.999848
# 2021-11-22 15:45:00 -0.370052 -0.143113 -0.252981  5  1.5        6  0.999657
# 2021-11-22 16:45:00 -1.805293 -0.919093 -0.794770  5  2.0        8  0.999391
# 2021-11-22 17:45:00  0.364801  0.371707 -1.171848  5  2.5       10  0.999048
# 2021-11-22 18:45:00  2.010939  0.925543 -2.027292  5  3.0       12  0.998630
# 2021-11-22 19:45:00 -0.071329  0.038003  0.580118  5  3.5       14  0.998135
# 2021-11-22 20:45:00  1.445956 -1.040189  0.228217  5  4.0       16  0.997564
# 2021-11-22 21:45:00  0.182061 -0.288185 -0.268817  5  4.5       18  0.996917

# %% [markdown]
# ### Dropping
#
# N.B.: dropping doesn't act permanently on the DataFrame, i.e. to get that do :
# ```python
# df = df.drop(....)
# ```

# %%
# Dropping by column
df.drop(['E prime'], axis=1)

#which is equivalent to
new_df=df.drop(columns=['E prime']) #new table dose not have E prime
new_df
# Out:
#                             A         B         C  D    E    cosine
# 2021-11-22 12:45:00  0.000000  0.979761  0.154588  5  0.0  1.000000
# 2021-11-22 13:45:00  0.983646 -0.021242  0.058003  5  0.5  0.999962
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  5  1.0  0.999848
# 2021-11-22 15:45:00 -0.370052 -0.143113 -0.252981  5  1.5  0.999657
# 2021-11-22 16:45:00 -1.805293 -0.919093 -0.794770  5  2.0  0.999391
# 2021-11-22 17:45:00  0.364801  0.371707 -1.171848  5  2.5  0.999048
# 2021-11-22 18:45:00  2.010939  0.925543 -2.027292  5  3.0  0.998630
# 2021-11-22 19:45:00 -0.071329  0.038003  0.580118  5  3.5  0.998135
# 2021-11-22 20:45:00  1.445956 -1.040189  0.228217  5  4.0  0.997564
# 2021-11-22 21:45:00  0.182061 -0.288185 -0.268817  5  4.5  0.996917

# %%
# Dropping by raws
# safe and always working
df.drop(df.index[[1,2,3,4]])
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2021-11-22 12:45:00  0.000000  0.979761  0.154588  5  0.0        0  1.000000
# 2021-11-22 17:45:00  0.364801  0.371707 -1.171848  5  2.5       10  0.999048
# 2021-11-22 18:45:00  2.010939  0.925543 -2.027292  5  3.0       12  0.998630
# 2021-11-22 19:45:00 -0.071329  0.038003  0.580118  5  3.5       14  0.998135
# 2021-11-22 20:45:00  1.445956 -1.040189  0.228217  5  4.0       16  0.997564
# 2021-11-22 21:45:00  0.182061 -0.288185 -0.268817  5  4.5       18  0.996917

# %%
df

# %%
# something like df.drop('index_name') 
# would work but the type of index must be specificed, 
# in particular with DatetimeIndex
df.drop(pd.to_datetime("2021-11-22 20:45:00"))

# %% [markdown]
# ## Missing data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations.

# %%
df_wNan = df[df>0]
df_wNan
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2021-11-22 12:45:00       NaN  0.979761  0.154588  5  NaN      NaN  1.000000
# 2021-11-22 13:45:00  0.983646       NaN  0.058003  5  0.5      2.0  0.999962
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  5  1.0      4.0  0.999848
# 2021-11-22 15:45:00       NaN       NaN       NaN  5  1.5      6.0  0.999657
# 2021-11-22 16:45:00       NaN       NaN       NaN  5  2.0      8.0  0.999391
# 2021-11-22 17:45:00  0.364801  0.371707       NaN  5  2.5     10.0  0.999048
# 2021-11-22 18:45:00  2.010939  0.925543       NaN  5  3.0     12.0  0.998630
# 2021-11-22 19:45:00       NaN  0.038003  0.580118  5  3.5     14.0  0.998135
# 2021-11-22 20:45:00  1.445956       NaN  0.228217  5  4.0     16.0  0.997564
# 2021-11-22 21:45:00  0.182061       NaN       NaN  5  4.5     18.0  0.996917

# %%
# dropping raws with at least a Nan
df_wNan.dropna(how='any')
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  5  1.0      4.0  0.999848

# %%
# getting a mask
df_wNan.isna()
#df_wNan.notna()
# Out:
#                          A      B      C      D      E  E prime  cosine
# 2021-11-22 12:45:00   True  False  False  False   True     True   False
# 2021-11-22 13:45:00  False   True  False  False  False    False   False
# 2021-11-22 14:45:00  False  False  False  False  False    False   False
# 2021-11-22 15:45:00   True   True   True  False  False    False   False
# 2021-11-22 16:45:00   True   True   True  False  False    False   False
# 2021-11-22 17:45:00  False  False   True  False  False    False   False
# 2021-11-22 18:45:00  False  False   True  False  False    False   False
# 2021-11-22 19:45:00   True  False  False  False  False    False   False
# 2021-11-22 20:45:00  False   True  False  False  False    False   False
# 2021-11-22 21:45:00  False   True   True  False  False    False   False

# %%
# filling missing data
df_wNan.fillna(value=0)
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2021-11-22 12:45:00  0.000000  0.979761  0.154588  5  0.0      0.0  1.000000
# 2021-11-22 13:45:00  0.983646  0.000000  0.058003  5  0.5      2.0  0.999962
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  5  1.0      4.0  0.999848
# 2021-11-22 15:45:00  0.000000  0.000000  0.000000  5  1.5      6.0  0.999657
# 2021-11-22 16:45:00  0.000000  0.000000  0.000000  5  2.0      8.0  0.999391
# 2021-11-22 17:45:00  0.364801  0.371707  0.000000  5  2.5     10.0  0.999048
# 2021-11-22 18:45:00  2.010939  0.925543  0.000000  5  3.0     12.0  0.998630
# 2021-11-22 19:45:00  0.000000  0.038003  0.580118  5  3.5     14.0  0.998135
# 2021-11-22 20:45:00  1.445956  0.000000  0.228217  5  4.0     16.0  0.997564
# 2021-11-22 21:45:00  0.182061  0.000000  0.000000  5  4.5     18.0  0.996917

# %% [markdown]
# Fill gaps forward or backward by propagating non-NA values forward or backward:

# %%
df_wNan.fillna(method='pad')
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2021-11-22 12:45:00       NaN  0.979761  0.154588  5  NaN      NaN  1.000000
# 2021-11-22 13:45:00  0.983646  0.979761  0.058003  5  0.5      2.0  0.999962
# 2021-11-22 14:45:00  0.231458  0.683868  0.843007  5  1.0      4.0  0.999848
# 2021-11-22 15:45:00  0.231458  0.683868  0.843007  5  1.5      6.0  0.999657
# 2021-11-22 16:45:00  0.231458  0.683868  0.843007  5  2.0      8.0  0.999391
# 2021-11-22 17:45:00  0.364801  0.371707  0.843007  5  2.5     10.0  0.999048
# 2021-11-22 18:45:00  2.010939  0.925543  0.843007  5  3.0     12.0  0.998630
# 2021-11-22 19:45:00  2.010939  0.038003  0.580118  5  3.5     14.0  0.998135
# 2021-11-22 20:45:00  1.445956  0.038003  0.228217  5  4.0     16.0  0.997564
# 2021-11-22 21:45:00  0.182061  0.038003  0.228217  5  4.5     18.0  0.996917

# %% [markdown]
# ## Operations
#
# Here comes the most relevant advantage of DataFrame. Operations on columns are extremly fast, almost as fast as the actual operation between elements in a raw

# %%
# Some statistics (mean() just as an example)
# raws
print (df.mean(axis=0),'\n')
# columns
print (df.mean(axis=1),'\n')
# Out:
# A          0.297219
# B          0.058706
# C         -0.265177
# D          5.000000
# E          2.250000
# E prime    9.000000
# cosine     0.998915
# dtype: float64
#
# 2021-11-22 12:45:00    1.019193
# 2021-11-22 13:45:00    1.360053
# 2021-11-22 14:45:00    1.822597
# 2021-11-22 15:45:00    1.819073
# 2021-11-22 16:45:00    1.782891
# 2021-11-22 17:45:00    2.580530
# 2021-11-22 18:45:00    3.129688
# 2021-11-22 19:45:00    3.434989
# 2021-11-22 20:45:00    3.804507
# 2021-11-22 21:45:00    4.017425
# Freq: H, dtype: float64

# %%
# global operations on columns
df.apply(np.cumsum)#elemane avalio ba domi ba sevomi , ....jam mikone
# Out:
#                             A         B         C   D     E  E prime    cosine
# 2021-11-22 12:45:00  0.000000  0.979761  0.154588   5   0.0        0  1.000000
# 2021-11-22 13:45:00  0.983646  0.958519  0.212591  10   0.5        2  1.999962
# 2021-11-22 14:45:00  1.215103  1.642387  1.055598  15   1.5        6  2.999810
# 2021-11-22 15:45:00  0.845051  1.499274  0.802617  20   3.0       12  3.999467
# 2021-11-22 16:45:00 -0.960242  0.580181  0.007847  25   5.0       20  4.998858
# 2021-11-22 17:45:00 -0.595441  0.951888 -1.164000  30   7.5       30  5.997906
# 2021-11-22 18:45:00  1.415498  1.877431 -3.191292  35  10.5       42  6.996536
# 2021-11-22 19:45:00  1.344169  1.915433 -2.611174  40  14.0       56  7.994670
# 2021-11-22 20:45:00  2.790124  0.875245 -2.382957  45  18.0       72  8.992234
# 2021-11-22 21:45:00  2.972185  0.587060 -2.651774  50  22.5       90  9.989152

# %%
df

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A           3.816232
# B           2.019950
# C           2.870299
# D           0.000000
# E           4.500000
# E prime    18.000000
# cosine      0.003083
# dtype: float64

# %%
# syntax is as usual similar to that of numpy arrays
df['A']+df['B']

# %% [markdown]
# Let's play it hard and load (in memory) a (relatively) large dataset

# %%
# WARNING! link in past notebook was wrong!, (if needed) get the right file from:
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

file_name="~/data/data_000637.txt"
data=pd.read_csv(file_name)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-46e7609bac93> in <module>
#       3
#       4 file_name="~/data/data_000637.txt"
# ----> 5 data=pd.read_csv(file_name)
#       6 data
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %% [markdown]
# Let's now do some operations among (elements of) columns

# %%
# the one-liner killing it all
data['timens']=data['TDC_MEAS']*25/30+data['BX_COUNTER']*25 #just operation between two  variables of our data

# %%
data['timens']

# %%
# the old slooow way
def conversion(data):
    result=[]
    for i in range(len(data)): 
        result.append(data.loc[data.index[i],'TDC_MEAS']*25/30.+data.loc[data.index[i],'BX_COUNTER']*25)
    return result

data['timens']=conversion(data)

# %% [markdown]
# ## Merge
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# ### Concat
#
# concatenation (adding rows) is straightforward

# %%
rdf = pd.DataFrame(np.random.randn(10, 4))
rdf
# Out:
#           0         1         2         3
# 0 -0.373473  1.076887  1.230534 -0.751440
# 1  0.902107 -1.971669 -0.355531  0.841379
# 2 -1.548428 -1.644091  1.444352 -0.560887
# 3  0.495005 -1.723844 -0.667010  0.632866
# 4 -1.330574 -0.009007  0.198783 -1.468759
# 5  0.818136 -0.928559  0.923767 -0.740032
# 6 -0.049116  0.840621 -0.289835 -1.491040
# 7 -0.141019 -0.084867  0.313711  1.406841
# 8 -1.594497 -1.720901 -3.210652  1.537130
# 9  1.178141  0.854446  2.023761  1.088166

# %%
# divide it into pieaces raw-wise
pieces = [rdf[:3], rdf[3:7], rdf[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -0.373473  1.076887  1.230534 -0.751440
#  1  0.902107 -1.971669 -0.355531  0.841379
#  2 -1.548428 -1.644091  1.444352 -0.560887,
#            0         1         2         3
#  3  0.495005 -1.723844 -0.667010  0.632866
#  4 -1.330574 -0.009007  0.198783 -1.468759
#  5  0.818136 -0.928559  0.923767 -0.740032
#  6 -0.049116  0.840621 -0.289835 -1.491040,
#            0         1         2         3
#  7 -0.141019 -0.084867  0.313711  1.406841
#  8 -1.594497 -1.720901 -3.210652  1.537130
#  9  1.178141  0.854446  2.023761  1.088166]

# %%
# put it back together
#pd.concat(pieces)

# indexes can be ignored
pd.concat(pieces, ignore_index=True)

# in case of dimension mismatch, Nan are added where needed
# Out:
#           0         1         2         3
# 0 -0.373473  1.076887  1.230534 -0.751440
# 1  0.902107 -1.971669 -0.355531  0.841379
# 2 -1.548428 -1.644091  1.444352 -0.560887
# 3  0.495005 -1.723844 -0.667010  0.632866
# 4 -1.330574 -0.009007  0.198783 -1.468759
# 5  0.818136 -0.928559  0.923767 -0.740032
# 6 -0.049116  0.840621 -0.289835 -1.491040
# 7 -0.141019 -0.084867  0.313711  1.406841
# 8 -1.594497 -1.720901 -3.210652  1.537130
# 9  1.178141  0.854446  2.023761  1.088166

# %%
# appending a single row (as a Series)
s = rdf.iloc[3]
rdf.append(s, ignore_index=True)
rdf

# %% [markdown]
# ### Merge/Join
#
# SQL like operations on table can be performed on DataFrames. This is all rather sophisticated, refer to the [doc](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging) for more info/examples

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
print(left)
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
print(right)
pd.merge(left,right,on="key")
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2
#    key  rval
# 0  foo     4
# 1  bar     5
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps:
#
# * Splitting the data into groups based on some criteria
# * Applying a function to each group independently
# * Combining the results into a data structure

# %%
gdf = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})
gdf #seperate two groups and then put data in these two group
# Out:
#      A      B         C         D
# 0  foo    one  1.847104 -1.276405
# 1  bar    one -0.633522 -0.564359
# 2  foo    two  1.012843 -1.816251
# 3  bar  three  0.918775 -0.087553
# 4  foo    two -0.846273  1.240650
# 5  bar    two -0.677873  0.466883
# 6  foo    one  1.142695 -1.130637
# 7  foo  three  1.055748  1.463031

# %%
# Grouping and then applying the sum() 
# function to the resulting groups (effective only where number are there).
gdf.groupby('A').sum() #because A just have foo & bar
# Out:
#             C         D
# A
# bar -0.392621 -0.185029
# foo  4.212117 -1.519613

# %% [markdown]
# ## Multi-indexing
#
#
# Hierarchical / Multi-level indexing allows sophisticated data analysis on higher dimensional data. In essence, it enables you to store and manipulate data with an arbitrary number of dimensions in lower dimensional data structures like Series (1d) and DataFrame (2d).

# %%
tuples = list(zip(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']))
multi_index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
print (multi_index,'\n')

s = pd.Series(np.random.randn(8), index=multi_index)
print (s)
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])
#
# first  second
# bar    one      -1.125076
#        two       0.534645
# baz    one      -0.340358
#        two      -0.056929
# foo    one       0.415440
#        two       0.921794
# qux    one      -1.017154
#        two       0.140332
# dtype: float64

# %%
# it enables further features of the groupby method,
# e.g. when group-by by multiple columns
gdf.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.633522 -0.564359
#     three  0.918775 -0.087553
#     two   -0.677873  0.466883
# foo one    2.989798 -2.407042
#     three  1.055748  1.463031
#     two    0.166570 -0.575601

# %%
# stack() method “compresses” a level in the DataFrame’s columns
gdf.groupby(['A','B']).sum().stack()

# %% [markdown]
# ## Plotting
#
# Just a preview, more on the next lab class!

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

pdf=pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
pdf = pdf.cumsum()
plt.figure(); pdf.plot(); plt.legend(loc='best')
